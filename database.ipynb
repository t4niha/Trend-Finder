# %% [markdown]
# ## 1. Imports

# %%
from database_util import create_database, connect_database, drop_table, create_table, insert_csv, table_stats
from translation import translate_posts

# %% [markdown]
# ## 2. Set Up Database

# %%
create_database()
conn = connect_database()
drop_table(conn)
create_table(conn)
conn.close()
# Out:
# Database 'trend_finder' already exists
# No existing table 'final_trendingtopics' to drop
# New table 'final_trendingtopics' created

# %% [markdown]
# ## 3. Insert New Data

# %%
conn = connect_database()
table_stats(conn)
insert_csv(conn, csv_path="final_trendingtopics.csv")
conn.close()
# Out:
# 0 existing samples in 'final_trendingtopics'
# 10233 new samples added from 'final_trendingtopics.csv'

# %% [markdown]
# ## 4. Translation

# %%
conn = connect_database()
translate_posts(conn)
conn.close()
# Out:
# Found 10233 rows to check for translation
# Translating posts:   0%|          | 0/10233 [00:00<?, ?post/s]
