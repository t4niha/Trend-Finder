# %%
from database_util import create_database, connect_database, drop_table, create_table, insert_csv, table_stats
from translation import translate_posts

# %%
# Set up database
create_database()
conn = connect_database()
drop_table(conn)
create_table(conn)
conn.close()
# Out:
# Database 'trend_finder' already exists
# Existing table 'trending_topics' dropped
# New table 'trending_topics' created

# %%
# Insert new data
conn = connect_database()
table_stats(conn)
insert_csv(conn, csv_path="trending_topics.csv")
conn.close()
# Out:
# 0 existing samples in 'trending_topics'
# 10547 new samples added from 'trending_topics.csv'
# 48 skipped due to conflicts

# %%
# Translation
conn = connect_database()
translate_posts(conn)
conn.close()
# Out:
# Found 10547 rows to check for translation
# Translating posts: 100%|██████████| 10547/10547 [08:30<00:00, 20.66post/s]
# Translated to English: 2035
# Already in English: 8500
# Unknown: 12
